# %% [markdown]
# # Workshop 05

# %% [markdown]
# <b>Obiettivo</b>: Realizzazione della pianta di <i><b>Villa Gazzotti Grimani</b></i>.

# %% [markdown]
# ![VillaGazzotti_pianta.jpg](files/Immagini/VillaGazzotti_pianta.jpg)

# %%
# Importo le librerie:
import sys
sys.path.insert(0, 'C:\Users\Camilla Bianca\Documents\GGPL\lar-cc\larlib')
from larlib import *
import math
import csv
# Out:
# Evaluating fenvs.py..
# ...fenvs.py imported in 0.0236074603309 seconds

# %%
with open("piantaSenzaSpiazzo.lines","rb") as file:
    reader = csv.reader(file,delimiter=",")
    muri = []
    for row in reader:
        row0 = math.floor(float(row[0])*10)/10
        row1 = math.floor(float(row[1])*10)/10
        row2 = math.floor(float(row[2])*10)/10
        row3 = math.floor(float(row[3])*10)/10
        muri.append(POLYLINE([[row0,row1],[row2,row3]]))
        
VIEW(STRUCT(muri))
# Out:
# <pyplasm.xgepy.Hpc; proxy of <Swig Object of type 'std::shared_ptr< Hpc > *' at 0x000000000E6F44B0> >

# %% [markdown]
# ![ws5_pianta.png](files/Immagini/ws5_pianta.png)

# %%
altezza = 100
VIEW(MULTEXTRUDE(OFFSET([2,2])(STRUCT(muri)))(altezza))
# Out:
# <pyplasm.xgepy.Hpc; proxy of <Swig Object of type 'std::shared_ptr< Hpc > *' at 0x000000000E7070F0> >

# %% [markdown]
# ![ws5_piantaH.png](files/Immagini/ws5_piantaH.png)
